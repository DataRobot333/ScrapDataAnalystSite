# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=27"

# %%
response = requests.get(url)
response.raise_for_status()  # Raise an HTTPError for bad responses
soup = BeautifulSoup(response.text, 'html.parser')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
job_elements = soup.find_all('div', class_='jobs-wrapper')
len(job_elements) # should be 1 becuase we have just one table in page
# Out:
# 1

# %%
type(job_elements)
# Out:
# bs4.element.ResultSet

# %%
jobs = job_elements[0].find_all('a', class_ = 'card job cms-jobs-counter w-inline-block')
len(jobs) # must be 15 because each job in each page is 15
# Out:
# 15

# %%
type(jobs)
# Out:
# bs4.element.ResultSet

# %%
for job in jobs:
    print(job)
# Out:
# <a class="card job cms-jobs-counter w-inline-block" href="/job/data-analyst-pricing-and-promotions"><div class="html-embed-5 w-embed"><input class="nocodelytics-list-item" type="hidden" value="data-analyst-pricing-and-promotions"/></div><div class="html-embed-4 w-embed"><input class="jetboost-list-item" type="hidden" value="data-analyst-pricing-and-promotions"/></div><div class="split-content card-job-left"><div class="image-wrapper card-job-mobile-image"><img alt=" Data Analyst, Pricing and Promotions at etrailer" class="image card-job" height="75" loading="lazy" src="https://cdn.prod.website-files.com/6357ed6d70d64dc6b11de190/65c49de240c072c471cb4eb5_BCwjpvAF9kKaEDC4VOd9-Mm1qBNoPr1WkCkbYAmXmzc.jpeg" width="75"/></div><div class="card-job-title-wrapper"><div class="card-link-wrapper-mobile-standard"><div class="card-link-home">etrailer</div></div><h3 class="title h6-size card-job"> Data Analyst, Pricing and Promotions</h3><div class="card-link-wrapper"><div class="card-link-home">etrailer</div></div></div></div><div class="split-content card-job-right"><div class="card-job-category-wrapper"><div class="card-job-category-title-wrapper"><div>Country</div></div><div class="card-job-category-text">United States</div></div><div class="card-job-category-wrapper-location"><div class="card-job-category-title-wrapper"><div>Location</div></div><div class="card-job-category-text">Wentzville, MO</div></div><div class="card-job-category-wrapper-workplace"><div class="card-job-category-title-wrapper"><div>Workplace</div></div><div class="card-job-category-text">In-office</div></div><div class="card-job-category-wrapper-experience"><div class="card-job-category-title-wrapper"><div>Experience</div></div><div class="card-job-category-text">3 - 5 years</div></div><div class="card-job-category-wrapper-industry"><div class="card-job-category-title-wrapper"><div>Industry</div></div><div class="card-job-category-text">Retail</div></div><div class="card-job-category-wrapper-salary"><div class="card-job-category-title-wrapper"><div>Salary</div></div><div class="card-job-category-text">$65,000 - $65,000</div></div><div class="card-job-category-wrapper-published"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text">Feb 8, 2024</div></div><div class="card-job-category-wrapper-published-expired w-condition-invisible"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text-expired">Active</div></div></div></a>
# <a class="card job cms-jobs-counter w-inline-block" href="/job/data-analyst-health-21ba7"><div class="html-embed-5 w-embed"><input class="nocodelytics-list-item" type="hidden" value="data-analyst-health-21ba7"/></div><div class="html-embed-4 w-embed"><input class="jetboost-list-item" type="hidden" value="data-analyst-health-21ba7"/></div><div class="split-content card-job-left"><div class="image-wrapper card-job-mobile-image"><img alt=" Data Analyst, Health at Health Share of Oregon" class="image card-job" height="75" loading="lazy" src="https://cdn.prod.website-files.com/6357ed6d70d64dc6b11de190/65c350106b3a3d371c301e83_emD_nDbfD85DrNm09R3Pn_NMZuv-Y7yIGGYbnYg-BTI.jpeg" width="75"/></div><div class="card-job-title-wrapper"><div class="card-link-wrapper-mobile-standard"><div class="card-link-home">Health Share of Oregon</div></div><h3 class="title h6-size card-job"> Data Analyst, Health</h3><div class="card-link-wrapper"><div class="card-link-home">Health Share of Oregon</div></div></div></div><div class="split-content card-job-right"><div class="card-job-category-wrapper"><div class="card-job-category-title-wrapper"><div>Country</div></div><div class="card-job-category-text">United States</div></div><div class="card-job-category-wrapper-location"><div class="card-job-category-title-wrapper"><div>Location</div></div><div class="card-job-category-text">Portland, OR</div></div><div class="card-job-category-wrapper-workplace"><div class="card-job-category-title-wrapper"><div>Workplace</div></div><div class="card-job-category-text">Hybrid</div></div><div class="card-job-category-wrapper-experience"><div class="card-job-category-title-wrapper"><div>Experience</div></div><div class="card-job-category-text">3 - 5 years</div></div><div class="card-job-category-wrapper-industry"><div class="card-job-category-title-wrapper"><div>Industry</div></div><div class="card-job-category-text">Healthcare</div></div><div class="card-job-category-wrapper-salary"><div class="card-job-category-title-wrapper"><div>Salary</div></div><div class="card-job-category-text">$78,910 - $95,480</div></div><div class="card-job-category-wrapper-published"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text">Feb 7, 2024</div></div><div class="card-job-category-wrapper-published-expired w-condition-invisible"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text-expired">Active</div></div></div></a>
# <a class="card job cms-jobs-counter w-inline-block" href="/job/senior-data-analyst-marketing-6266d"><div class="html-embed-5 w-embed"><input class="nocodelytics-list-item" type="hidden" value="senior-data-analyst-marketing-6266d"/></div><div class="html-embed-4 w-embed"><input class="jetboost-list-item" type="hidden" value="senior-data-analyst-marketing-6266d"/></div><div class="split-content card-job-left"><div class="image-wrapper card-job-mobile-image"><img alt="Senior Data Analyst, Marketing at New York Life" class="image card-job" height="75" loading="lazy" src="https://cdn.prod.website-files.com/6357ed6d70d64dc6b11de190/65b1500827737e09d511ec14_yeJdX_lFhVYgd9CLUfP2jD2dpUnOBndbiLdRZj6LWJc.jpeg" width="75"/></div><div class="card-job-title-wrapper"><div class="card-link-wrapper-mobile-standard"><div class="card-link-home">New York Life</div></div><h3 class="title h6-size card-job">Senior Data Analyst, Marketing</h3><div class="card-link-wrapper"><div class="card-link-home">New York Life</div></div></div></div><div class="split-content card-job-right"><div class="card-job-category-wrapper"><div class="card-job-category-title-wrapper"><div>Country</div></div><div class="card-job-category-text">United States</div></div><div class="card-job-category-wrapper-location"><div class="card-job-category-title-wrapper"><div>Location</div></div><div class="card-job-category-text"> New York, NY</div></div><div class="card-job-category-wrapper-workplace"><div class="card-job-category-title-wrapper"><div>Workplace</div></div><div class="card-job-category-text">Hybrid</div></div><div class="card-job-category-wrapper-experience"><div class="card-job-category-title-wrapper"><div>Experience</div></div><div class="card-job-category-text">5 - 10 years</div></div><div class="card-job-category-wrapper-industry"><div class="card-job-category-title-wrapper"><div>Industry</div></div><div class="card-job-category-text">Insurance</div></div><div class="card-job-category-wrapper-salary"><div class="card-job-category-title-wrapper"><div>Salary</div></div><div class="card-job-category-text">$90,000 - $135,000</div></div><div class="card-job-category-wrapper-published"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text">Jan 24, 2024</div></div><div class="card-job-category-wrapper-published-expired w-condition-invisible"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text-expired">Active</div></div></div></a>
# <a class="card job cms-jobs-counter w-inline-block" href="/job/data-analyst-fraud-ecf58"><div class="html-embed-5 w-embed"><input class="nocodelytics-list-item" type="hidden" value="data-analyst-fraud-ecf58"/></div><div class="html-embed-4 w-embed"><input class="jetboost-list-item" type="hidden" value="data-analyst-fraud-ecf58"/></div><div class="split-content card-job-left"><div class="image-wrapper card-job-mobile-image"><img alt=" Data Analyst, Fraud at Ria Money Transfer" class="image card-job" height="75" loading="lazy" src="https://cdn.prod.website-files.com/6357ed6d70d64dc6b11de190/65b17b6be5d2b75ac9f8eb58_sO8r3V9j72965bdj5hgkWA21UjzpOefMufJywrqXlwE.jpeg" width="75"/></div><div class="card-job-title-wrapper"><div class="card-link-wrapper-mobile-standard"><div class="card-link-home">Ria Money Transfer</div></div><h3 class="title h6-size card-job"> Data Analyst, Fraud</h3><div class="card-link-wrapper"><div class="card-link-home">Ria Money Transfer</div></div></div></div><div class="split-content card-job-right"><div class="card-job-category-wrapper"><div class="card-job-category-title-wrapper"><div>Country</div></div><div class="card-job-category-text">United States</div></div><div class="card-job-category-wrapper-location"><div class="card-job-category-title-wrapper"><div>Location</div></div><div class="card-job-category-text">Denver, CO</div></div><div class="card-job-category-wrapper-workplace"><div class="card-job-category-title-wrapper"><div>Workplace</div></div><div class="card-job-category-text">Hybrid</div></div><div class="card-job-category-wrapper-experience"><div class="card-job-category-title-wrapper"><div>Experience</div></div><div class="card-job-category-text">5 - 10 years</div></div><div class="card-job-category-wrapper-industry"><div class="card-job-category-title-wrapper"><div>Industry</div></div><div class="card-job-category-text">Financial</div></div><div class="card-job-category-wrapper-salary"><div class="card-job-category-title-wrapper"><div>Salary</div></div><div class="card-job-category-text">$95,000 - $115,000</div></div><div class="card-job-category-wrapper-published"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text">Jan 18, 2024</div></div><div class="card-job-category-wrapper-published-expired w-condition-invisible"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text-expired">Active</div></div></div></a>
# <a class="card job cms-jobs-counter w-inline-block" href="/job/data-analyst-a62fc"><div class="html-embed-5 w-embed"><input class="nocodelytics-list-item" type="hidden" value="data-analyst-a62fc"/></div><div class="html-embed-4 w-embed"><input class="jetboost-list-item" type="hidden" value="data-analyst-a62fc"/></div><div class="split-content card-job-left"><div class="image-wrapper card-job-mobile-image"><img alt=" Data Analyst at Macmillan" class="image card-job" height="75" loading="lazy" src="https://cdn.prod.website-files.com/6357ed6d70d64dc6b11de190/65a7aa081edb823d3c77565a_T9Y1s5_Wm3aGNo_n4ps7W7DbtnOiNTTRO9k09ufHE4k.jpeg" width="75"/></div><div class="card-job-title-wrapper"><div class="card-link-wrapper-mobile-standard"><div class="card-link-home">Macmillan</div></div><h3 class="title h6-size card-job"> Data Analyst</h3><div class="card-link-wrapper"><div class="card-link-home">Macmillan</div></div></div></div><div class="split-content card-job-right"><div class="card-job-category-wrapper"><div class="card-job-category-title-wrapper"><div>Country</div></div><div class="card-job-category-text">United States</div></div><div class="card-job-category-wrapper-location"><div class="card-job-category-title-wrapper"><div>Location</div></div><div class="card-job-category-text"> New York, NY</div></div><div class="card-job-category-wrapper-workplace"><div class="card-job-category-title-wrapper"><div>Workplace</div></div><div class="card-job-category-text">Hybrid</div></div><div class="card-job-category-wrapper-experience"><div class="card-job-category-title-wrapper"><div>Experience</div></div><div class="card-job-category-text">5 - 10 years</div></div><div class="card-job-category-wrapper-industry"><div class="card-job-category-title-wrapper"><div>Industry</div></div><div class="card-job-category-text">Other</div></div><div class="card-job-category-wrapper-salary"><div class="card-job-category-title-wrapper"><div>Salary</div></div><div class="card-job-category-text">$110,000 - $120,000</div></div><div class="card-job-category-wrapper-published"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text">Jan 17, 2024</div></div><div class="card-job-category-wrapper-published-expired w-condition-invisible"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text-expired">Active</div></div></div></a>
# <a class="card job cms-jobs-counter w-inline-block" href="/job/data-analyst-trust-and-safety"><div class="html-embed-5 w-embed"><input class="nocodelytics-list-item" type="hidden" value="data-analyst-trust-and-safety"/></div><div class="html-embed-4 w-embed"><input class="jetboost-list-item" type="hidden" value="data-analyst-trust-and-safety"/></div><div class="split-content card-job-left"><div class="image-wrapper card-job-mobile-image"><img alt=" Data Analyst, Trust and Safety at Match Group" class="image card-job" height="75" loading="lazy" src="https://cdn.prod.website-files.com/6357ed6d70d64dc6b11de190/65b17b5b938f333fda669f65_skCDJfF9IlaK62gyECl1jjT-hw2TBjbTxIa5uS2mIaI.jpeg" width="75"/></div><div class="card-job-title-wrapper"><div class="card-link-wrapper-mobile-standard"><div class="card-link-home">Match Group</div></div><h3 class="title h6-size card-job"> Data Analyst, Trust and Safety</h3><div class="card-link-wrapper"><div class="card-link-home">Match Group</div></div></div></div><div class="split-content card-job-right"><div class="card-job-category-wrapper"><div class="card-job-category-title-wrapper"><div>Country</div></div><div class="card-job-category-text">United States</div></div><div class="card-job-category-wrapper-location"><div class="card-job-category-title-wrapper"><div>Location</div></div><div class="card-job-category-text"> San Francisco, CA</div></div><div class="card-job-category-wrapper-workplace"><div class="card-job-category-title-wrapper"><div>Workplace</div></div><div class="card-job-category-text">Hybrid</div></div><div class="card-job-category-wrapper-experience"><div class="card-job-category-title-wrapper"><div>Experience</div></div><div class="card-job-category-text">3 - 5 years</div></div><div class="card-job-category-wrapper-industry"><div class="card-job-category-title-wrapper"><div>Industry</div></div><div class="card-job-category-text">Entertainment</div></div><div class="card-job-category-wrapper-salary"><div class="card-job-category-title-wrapper"><div>Salary</div></div><div class="card-job-category-text">$105,000 - $124,500</div></div><div class="card-job-category-wrapper-published"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text">Jan 15, 2024</div></div><div class="card-job-category-wrapper-published-expired w-condition-invisible"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text-expired">Active</div></div></div></a>
# <a class="card job cms-jobs-counter w-inline-block" href="/job/senior-data-analyst-180d7"><div class="html-embed-5 w-embed"><input class="nocodelytics-list-item" type="hidden" value="senior-data-analyst-180d7"/></div><div class="html-embed-4 w-embed"><input class="jetboost-list-item" type="hidden" value="senior-data-analyst-180d7"/></div><div class="split-content card-job-left"><div class="image-wrapper card-job-mobile-image"><img alt="Senior Data Analyst at Cardinal Group" class="image card-job" height="75" loading="lazy" src="https://cdn.prod.website-files.com/6357ed6d70d64dc6b11de190/65aebf7cb7c174285343095f_noh9CFehtfjIF2rAcnwgD616iklauea_YfhW1HL049M.jpeg" width="75"/></div><div class="card-job-title-wrapper"><div class="card-link-wrapper-mobile-standard"><div class="card-link-home">Cardinal Group</div></div><h3 class="title h6-size card-job">Senior Data Analyst</h3><div class="card-link-wrapper"><div class="card-link-home">Cardinal Group</div></div></div></div><div class="split-content card-job-right"><div class="card-job-category-wrapper"><div class="card-job-category-title-wrapper"><div>Country</div></div><div class="card-job-category-text">United States</div></div><div class="card-job-category-wrapper-location"><div class="card-job-category-title-wrapper"><div>Location</div></div><div class="card-job-category-text">Denver, CO</div></div><div class="card-job-category-wrapper-workplace"><div class="card-job-category-title-wrapper"><div>Workplace</div></div><div class="card-job-category-text">Hybrid</div></div><div class="card-job-category-wrapper-experience"><div class="card-job-category-title-wrapper"><div>Experience</div></div><div class="card-job-category-text">3 - 5 years</div></div><div class="card-job-category-wrapper-industry"><div class="card-job-category-title-wrapper"><div>Industry</div></div><div class="card-job-category-text">Real Estate</div></div><div class="card-job-category-wrapper-salary"><div class="card-job-category-title-wrapper"><div>Salary</div></div><div class="card-job-category-text">$85,000 - $115,000</div></div><div class="card-job-category-wrapper-published"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text">Dec 29, 2023</div></div><div class="card-job-category-wrapper-published-expired w-condition-invisible"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text-expired">Active</div></div></div></a>
# <a class="card job cms-jobs-counter w-inline-block" href="/job/senior-data-analyst-31b85"><div class="html-embed-5 w-embed"><input class="nocodelytics-list-item" type="hidden" value="senior-data-analyst-31b85"/></div><div class="html-embed-4 w-embed"><input class="jetboost-list-item" type="hidden" value="senior-data-analyst-31b85"/></div><div class="split-content card-job-left"><div class="image-wrapper card-job-mobile-image"><img alt="Senior Data Analyst at Broadridge" class="image card-job" height="75" loading="lazy" src="https://cdn.prod.website-files.com/6357ed6d70d64dc6b11de190/658176312999a5b3cf52fd72_VGs1vDldNSTUW1j17Hl3RZNT7FlH39YHLTZebPpq_xE.jpeg" width="75"/></div><div class="card-job-title-wrapper"><div class="card-link-wrapper-mobile-standard"><div class="card-link-home">Broadridge</div></div><h3 class="title h6-size card-job">Senior Data Analyst</h3><div class="card-link-wrapper"><div class="card-link-home">Broadridge</div></div></div></div><div class="split-content card-job-right"><div class="card-job-category-wrapper"><div class="card-job-category-title-wrapper"><div>Country</div></div><div class="card-job-category-text">United States</div></div><div class="card-job-category-wrapper-location"><div class="card-job-category-title-wrapper"><div>Location</div></div><div class="card-job-category-text">New York, NY</div></div><div class="card-job-category-wrapper-workplace"><div class="card-job-category-title-wrapper"><div>Workplace</div></div><div class="card-job-category-text">Hybrid</div></div><div class="card-job-category-wrapper-experience"><div class="card-job-category-title-wrapper"><div>Experience</div></div><div class="card-job-category-text">3 - 5 years</div></div><div class="card-job-category-wrapper-industry"><div class="card-job-category-title-wrapper"><div>Industry</div></div><div class="card-job-category-text">Financial</div></div><div class="card-job-category-wrapper-salary"><div class="card-job-category-title-wrapper"><div>Salary</div></div><div class="card-job-category-text">$77,000 - $82,000</div></div><div class="card-job-category-wrapper-published"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text">Dec 19, 2023</div></div><div class="card-job-category-wrapper-published-expired w-condition-invisible"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text-expired">Active</div></div></div></a>
# <a class="card job cms-jobs-counter w-inline-block" href="/job/data-analyst-a2575"><div class="html-embed-5 w-embed"><input class="nocodelytics-list-item" type="hidden" value="data-analyst-a2575"/></div><div class="html-embed-4 w-embed"><input class="jetboost-list-item" type="hidden" value="data-analyst-a2575"/></div><div class="split-content card-job-left"><div class="image-wrapper card-job-mobile-image"><img alt=" Data Analyst at BAE Systems" class="image card-job" height="75" loading="lazy" src="https://cdn.prod.website-files.com/6357ed6d70d64dc6b11de190/65b17c58a3eeb2787074a80a_ql-Mm1uKiQtU_vCr0TAKaPgYy1BOiZB3YOdS36I79gE.jpeg" width="75"/></div><div class="card-job-title-wrapper"><div class="card-link-wrapper-mobile-standard"><div class="card-link-home">BAE Systems</div></div><h3 class="title h6-size card-job"> Data Analyst</h3><div class="card-link-wrapper"><div class="card-link-home">BAE Systems</div></div></div></div><div class="split-content card-job-right"><div class="card-job-category-wrapper"><div class="card-job-category-title-wrapper"><div>Country</div></div><div class="card-job-category-text">United States</div></div><div class="card-job-category-wrapper-location"><div class="card-job-category-title-wrapper"><div>Location</div></div><div class="card-job-category-text">Herndon, VA</div></div><div class="card-job-category-wrapper-workplace"><div class="card-job-category-title-wrapper"><div>Workplace</div></div><div class="card-job-category-text">In-office</div></div><div class="card-job-category-wrapper-experience"><div class="card-job-category-title-wrapper"><div>Experience</div></div><div class="card-job-category-text">5 - 10 years</div></div><div class="card-job-category-wrapper-industry"><div class="card-job-category-title-wrapper"><div>Industry</div></div><div class="card-job-category-text">Manufacturing</div></div><div class="card-job-category-wrapper-salary"><div class="card-job-category-title-wrapper"><div>Salary</div></div><div class="card-job-category-text">$136,620 - $232,210</div></div><div class="card-job-category-wrapper-published"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text">Dec 19, 2023</div></div><div class="card-job-category-wrapper-published-expired w-condition-invisible"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text-expired">Active</div></div></div></a>
# <a class="card job cms-jobs-counter w-inline-block" href="/job/senior-data-analyst-8ff14"><div class="html-embed-5 w-embed"><input class="nocodelytics-list-item" type="hidden" value="senior-data-analyst-8ff14"/></div><div class="html-embed-4 w-embed"><input class="jetboost-list-item" type="hidden" value="senior-data-analyst-8ff14"/></div><div class="split-content card-job-left"><div class="image-wrapper card-job-mobile-image"><img alt="Senior Data Analyst at Yum! Brands" class="image card-job" height="75" loading="lazy" src="https://cdn.prod.website-files.com/6357ed6d70d64dc6b11de190/657c21568df414b082ba8ddd_r1agiDoI0BCs70VvEkG1WYBO3rwaZ-lOU7hh_b-zrLQ.jpeg" width="75"/></div><div class="card-job-title-wrapper"><div class="card-link-wrapper-mobile-standard"><div class="card-link-home">Yum! Brands</div></div><h3 class="title h6-size card-job">Senior Data Analyst</h3><div class="card-link-wrapper"><div class="card-link-home">Yum! Brands</div></div></div></div><div class="split-content card-job-right"><div class="card-job-category-wrapper"><div class="card-job-category-title-wrapper"><div>Country</div></div><div class="card-job-category-text">United States</div></div><div class="card-job-category-wrapper-location"><div class="card-job-category-title-wrapper"><div>Location</div></div><div class="card-job-category-text"> Plano, TX</div></div><div class="card-job-category-wrapper-workplace"><div class="card-job-category-title-wrapper"><div>Workplace</div></div><div class="card-job-category-text">Hybrid</div></div><div class="card-job-category-wrapper-experience"><div class="card-job-category-title-wrapper"><div>Experience</div></div><div class="card-job-category-text">3 - 5 years</div></div><div class="card-job-category-wrapper-industry"><div class="card-job-category-title-wrapper"><div>Industry</div></div><div class="card-job-category-text">Other</div></div><div class="card-job-category-wrapper-salary"><div class="card-job-category-title-wrapper"><div>Salary</div></div><div class="card-job-category-text">$108,700 - $136,300</div></div><div class="card-job-category-wrapper-published"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text">Dec 15, 2023</div></div><div class="card-job-category-wrapper-published-expired w-condition-invisible"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text-expired">Active</div></div></div></a>
# <a class="card job cms-jobs-counter w-inline-block" href="/job/senior-data-analyst-22a2e"><div class="html-embed-5 w-embed"><input class="nocodelytics-list-item" type="hidden" value="senior-data-analyst-22a2e"/></div><div class="html-embed-4 w-embed"><input class="jetboost-list-item" type="hidden" value="senior-data-analyst-22a2e"/></div><div class="split-content card-job-left"><div class="image-wrapper card-job-mobile-image"><img alt="Senior Data Analyst at Tucows" class="image card-job" height="75" loading="lazy" src="https://cdn.prod.website-files.com/6357ed6d70d64dc6b11de190/6571a5aca80c32976888617f_fp6NmdnDR1XAGEJdgwKqzr9MzOmRmxwYp8z06oeH2uk.jpeg" width="75"/></div><div class="card-job-title-wrapper"><div class="card-link-wrapper-mobile-standard"><div class="card-link-home">Tucows</div></div><h3 class="title h6-size card-job">Senior Data Analyst</h3><div class="card-link-wrapper"><div class="card-link-home">Tucows</div></div></div></div><div class="split-content card-job-right"><div class="card-job-category-wrapper"><div class="card-job-category-title-wrapper"><div>Country</div></div><div class="card-job-category-text">United States</div></div><div class="card-job-category-wrapper-location"><div class="card-job-category-title-wrapper"><div>Location</div></div><div class="card-job-category-text">Remote</div></div><div class="card-job-category-wrapper-workplace"><div class="card-job-category-title-wrapper"><div>Workplace</div></div><div class="card-job-category-text">Remote</div></div><div class="card-job-category-wrapper-experience"><div class="card-job-category-title-wrapper"><div>Experience</div></div><div class="card-job-category-text">5 - 10 years</div></div><div class="card-job-category-wrapper-industry"><div class="card-job-category-title-wrapper"><div>Industry</div></div><div class="card-job-category-text">Tech</div></div><div class="card-job-category-wrapper-salary"><div class="card-job-category-title-wrapper"><div>Salary</div></div><div class="card-job-category-text">$99,900 - $111,000</div></div><div class="card-job-category-wrapper-published"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text">Dec 7, 2023</div></div><div class="card-job-category-wrapper-published-expired w-condition-invisible"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text-expired">Active</div></div></div></a>
# <a class="card job cms-jobs-counter w-inline-block" href="/job/senior-data-analyst-marketing-204a2"><div class="html-embed-5 w-embed"><input class="nocodelytics-list-item" type="hidden" value="senior-data-analyst-marketing-204a2"/></div><div class="html-embed-4 w-embed"><input class="jetboost-list-item" type="hidden" value="senior-data-analyst-marketing-204a2"/></div><div class="split-content card-job-left"><div class="image-wrapper card-job-mobile-image"><img alt="Senior Data Analyst, Marketing at Remitly" class="image card-job" height="75" loading="lazy" src="https://cdn.prod.website-files.com/6357ed6d70d64dc6b11de190/65b17a0745a0e1b5f6f4f7ca_26JQLnPoIpOd0znP8HCxeQVomp1SQRhyAw1KWV2x96w.jpeg" width="75"/></div><div class="card-job-title-wrapper"><div class="card-link-wrapper-mobile-standard"><div class="card-link-home">Remitly</div></div><h3 class="title h6-size card-job">Senior Data Analyst, Marketing</h3><div class="card-link-wrapper"><div class="card-link-home">Remitly</div></div></div></div><div class="split-content card-job-right"><div class="card-job-category-wrapper"><div class="card-job-category-title-wrapper"><div>Country</div></div><div class="card-job-category-text">United States</div></div><div class="card-job-category-wrapper-location"><div class="card-job-category-title-wrapper"><div>Location</div></div><div class="card-job-category-text">Seattle, WA</div></div><div class="card-job-category-wrapper-workplace"><div class="card-job-category-title-wrapper"><div>Workplace</div></div><div class="card-job-category-text">In-office</div></div><div class="card-job-category-wrapper-experience"><div class="card-job-category-title-wrapper"><div>Experience</div></div><div class="card-job-category-text">5 - 10 years</div></div><div class="card-job-category-wrapper-industry"><div class="card-job-category-title-wrapper"><div>Industry</div></div><div class="card-job-category-text">Financial</div></div><div class="card-job-category-wrapper-salary"><div class="card-job-category-title-wrapper"><div>Salary</div></div><div class="card-job-category-text">$120,000 - $150,000</div></div><div class="card-job-category-wrapper-published"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text">Dec 1, 2023</div></div><div class="card-job-category-wrapper-published-expired w-condition-invisible"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text-expired">Active</div></div></div></a>
# <a class="card job cms-jobs-counter w-inline-block" href="/job/data-analyst-e639f"><div class="html-embed-5 w-embed"><input class="nocodelytics-list-item" type="hidden" value="data-analyst-e639f"/></div><div class="html-embed-4 w-embed"><input class="jetboost-list-item" type="hidden" value="data-analyst-e639f"/></div><div class="split-content card-job-left"><div class="image-wrapper card-job-mobile-image"><img alt=" Data Analyst at Stagwell" class="image card-job" height="75" loading="lazy" src="https://cdn.prod.website-files.com/6357ed6d70d64dc6b11de190/6568672db9e2ae9f12fc0214_RSoH854dpLp8nScUJBdmFvsQuZL5AiOajnbbLVW82vo.jpeg" width="75"/></div><div class="card-job-title-wrapper"><div class="card-link-wrapper-mobile-standard"><div class="card-link-home">Stagwell</div></div><h3 class="title h6-size card-job"> Data Analyst</h3><div class="card-link-wrapper"><div class="card-link-home">Stagwell</div></div></div></div><div class="split-content card-job-right"><div class="card-job-category-wrapper"><div class="card-job-category-title-wrapper"><div>Country</div></div><div class="card-job-category-text">United States</div></div><div class="card-job-category-wrapper-location"><div class="card-job-category-title-wrapper"><div>Location</div></div><div class="card-job-category-text">New York, NY</div></div><div class="card-job-category-wrapper-workplace"><div class="card-job-category-title-wrapper"><div>Workplace</div></div><div class="card-job-category-text">Hybrid</div></div><div class="card-job-category-wrapper-experience"><div class="card-job-category-title-wrapper"><div>Experience</div></div><div class="card-job-category-text">5 - 10 years</div></div><div class="card-job-category-wrapper-industry"><div class="card-job-category-title-wrapper"><div>Industry</div></div><div class="card-job-category-text">Marketing</div></div><div class="card-job-category-wrapper-salary"><div class="card-job-category-title-wrapper"><div>Salary</div></div><div class="card-job-category-text">$104,000 - $130,000</div></div><div class="card-job-category-wrapper-published"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text">Nov 30, 2023</div></div><div class="card-job-category-wrapper-published-expired w-condition-invisible"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text-expired">Active</div></div></div></a>
# <a class="card job cms-jobs-counter w-inline-block" href="/job/data-analyst-08ebb"><div class="html-embed-5 w-embed"><input class="nocodelytics-list-item" type="hidden" value="data-analyst-08ebb"/></div><div class="html-embed-4 w-embed"><input class="jetboost-list-item" type="hidden" value="data-analyst-08ebb"/></div><div class="split-content card-job-left"><div class="image-wrapper card-job-mobile-image"><img alt=" Data Analyst at Hydrafacial" class="image card-job" height="75" loading="lazy" src="https://cdn.prod.website-files.com/6357ed6d70d64dc6b11de190/6565bcdefe3d8e0be49b1670_el_NcY0cCjVT6r4D3sWS7K5M2RQNwW6nh-YroppKpic.jpeg" width="75"/></div><div class="card-job-title-wrapper"><div class="card-link-wrapper-mobile-standard"><div class="card-link-home">Hydrafacial</div></div><h3 class="title h6-size card-job"> Data Analyst</h3><div class="card-link-wrapper"><div class="card-link-home">Hydrafacial</div></div></div></div><div class="split-content card-job-right"><div class="card-job-category-wrapper"><div class="card-job-category-title-wrapper"><div>Country</div></div><div class="card-job-category-text">United States</div></div><div class="card-job-category-wrapper-location"><div class="card-job-category-title-wrapper"><div>Location</div></div><div class="card-job-category-text">Long Beach, CA</div></div><div class="card-job-category-wrapper-workplace"><div class="card-job-category-title-wrapper"><div>Workplace</div></div><div class="card-job-category-text">In-office</div></div><div class="card-job-category-wrapper-experience"><div class="card-job-category-title-wrapper"><div>Experience</div></div><div class="card-job-category-text">5 - 10 years</div></div><div class="card-job-category-wrapper-industry"><div class="card-job-category-title-wrapper"><div>Industry</div></div><div class="card-job-category-text">Other</div></div><div class="card-job-category-wrapper-salary"><div class="card-job-category-title-wrapper"><div>Salary</div></div><div class="card-job-category-text">$68,000 - $78,000</div></div><div class="card-job-category-wrapper-published"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text">Nov 28, 2023</div></div><div class="card-job-category-wrapper-published-expired w-condition-invisible"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text-expired">Active</div></div></div></a>
# <a class="card job cms-jobs-counter w-inline-block" href="/job/senior-data-analyst-e7b7b"><div class="html-embed-5 w-embed"><input class="nocodelytics-list-item" type="hidden" value="senior-data-analyst-e7b7b"/></div><div class="html-embed-4 w-embed"><input class="jetboost-list-item" type="hidden" value="senior-data-analyst-e7b7b"/></div><div class="split-content card-job-left"><div class="image-wrapper card-job-mobile-image"><img alt="Senior Data Analyst at Leaf Trade" class="image card-job" height="75" loading="lazy" src="https://cdn.prod.website-files.com/6357ed6d70d64dc6b11de190/65647b4ede1d8981d653d491_0H3q9l5QIe00fPqrtCws79rXDDQCRbCkTlhyu2CgNPI.jpeg" width="75"/></div><div class="card-job-title-wrapper"><div class="card-link-wrapper-mobile-standard"><div class="card-link-home">Leaf Trade</div></div><h3 class="title h6-size card-job">Senior Data Analyst</h3><div class="card-link-wrapper"><div class="card-link-home">Leaf Trade</div></div></div></div><div class="split-content card-job-right"><div class="card-job-category-wrapper"><div class="card-job-category-title-wrapper"><div>Country</div></div><div class="card-job-category-text">United States</div></div><div class="card-job-category-wrapper-location"><div class="card-job-category-title-wrapper"><div>Location</div></div><div class="card-job-category-text">Remote</div></div><div class="card-job-category-wrapper-workplace"><div class="card-job-category-title-wrapper"><div>Workplace</div></div><div class="card-job-category-text">Remote</div></div><div class="card-job-category-wrapper-experience"><div class="card-job-category-title-wrapper"><div>Experience</div></div><div class="card-job-category-text">3 - 5 years</div></div><div class="card-job-category-wrapper-industry"><div class="card-job-category-title-wrapper"><div>Industry</div></div><div class="card-job-category-text">Tech</div></div><div class="card-job-category-wrapper-salary"><div class="card-job-category-title-wrapper"><div>Salary</div></div><div class="card-job-category-text">$90,000 - $100,000</div></div><div class="card-job-category-wrapper-published"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text">Nov 27, 2023</div></div><div class="card-job-category-wrapper-published-expired w-condition-invisible"><div class="card-job-category-title-wrapper"><img alt="clock icon" class="card-job-category-title-icon" src="https://cdn.prod.website-files.com/6357ed6d70d64d11de1de16e/6366984e71d5e931e89ef1ff_clock-blue-full.svg" width="12"/><div>Published</div></div><div class="card-job-category-text-expired">Active</div></div></div></a>

# %% [markdown]
# #### now it is ready to ask gemini.ai to extract every value for job in jobs.

# %% [markdown]
# # Task
# Scrape all data analyst job listings from the website "https://www.dataanalyst.com/data-analyst-jobs", iterating through all available pages, and save the collected information to a CSV file named 'job_listings.csv'.

# %% [markdown]
# ## Iterate through pages
#
# ### Subtask:
# Modify the web scraping script to iterate through the job listing pages, dynamically changing the 'page' parameter in the URL. This will likely involve a `while` loop that continues as long as job listings are found on a page.

# %% [markdown]
# **Reasoning**:
# The subtask requires modifying the web scraping script to iterate through multiple pages, collect all job listings, and handle potential errors. This code block will implement a while loop to achieve this, dynamically constructing URLs and extracting data until no more job listings are found.

# %%
import requests
from bs4 import BeautifulSoup

all_job_listings = []
page_number = 1

while True:
    url = f"https://www.dataanalyst.com/data-analyst-jobs?c834b559_page={page_number}"
    print(f"Scraping page: {page_number}, URL: {url}")

    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an HTTPError for bad responses (4xx or 5xx)

        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the main container for all job listings
        jobs_wrapper = soup.find('div', class_='jobs-wrapper')

        if jobs_wrapper:
            # Find all individual job cards (<a> tags) within the wrapper
            job_cards = jobs_wrapper.find_all('a', class_='card job cms-jobs-counter w-inline-block')

            if not job_cards:
                print(f"No job listings found on page {page_number}. Breaking loop.")
                break  # No more job listings, break the loop

            for job in job_cards:
                # Extract Job Title
                title_tag = job.find('h3', class_='title h6-size card-job')
                title = title_tag.get_text(strip=True) if title_tag else 'N/A'

                # Extract Company Name
                company_tag = job.find('div', class_='card-link-home')
                company = company_tag.get_text(strip=True) if company_tag else 'N/A'

                # Extract Location
                location_tag_container = job.find('div', class_='card-job-category-wrapper-location')
                location_tag = location_tag_container.find('div', class_='card-job-category-text') if location_tag_container else None
                location = location_tag.get_text(strip=True) if location_tag else 'N/A'

                # Extract Country
                country = 'N/A'
                country_label = job.find('div', string='Country')
                if country_label and country_label.find_next_sibling('div', class_='card-job-category-text'):
                    country = country_label.find_next_sibling('div', class_='card-job-category-text').get_text(strip=True)

                # Extract Workplace
                workplace_tag_container = job.find('div', class_='card-job-category-wrapper-workplace')
                workplace_tag = workplace_tag_container.find('div', class_='card-job-category-text') if workplace_tag_container else None
                workplace = workplace_tag.get_text(strip=True) if workplace_tag else 'N/A'

                # Extract Experience
                experience_tag_container = job.find('div', class_='card-job-category-wrapper-experience')
                experience_tag = experience_tag_container.find('div', class_='card-job-category-text') if experience_tag_container else None
                experience = experience_tag.get_text(strip=True) if experience_tag else 'N/A'

                # Extract Industry
                industry_tag_container = job.find('div', class_='card-job-category-wrapper-industry')
                industry_tag = industry_tag_container.find('div', class_='card-job-category-text') if industry_tag_container else None
                industry = industry_tag.get_text(strip=True) if industry_tag else 'N/A'

                # Extract Salary
                salary_tag_container = job.find('div', class_='card-job-category-wrapper-salary')
                salary_tag = salary_tag_container.find('div', class_='card-job-category-text') if salary_tag_container else None
                salary = salary_tag.get_text(strip=True) if salary_tag else 'N/A'

                # Extract Published Date
                published_tag_container = job.find('div', class_='card-job-category-wrapper-published')
                published_tag = published_tag_container.find('div', class_='card-job-category-text') if published_tag_container else None
                published_date = published_tag.get_text(strip=True) if published_tag else 'N/A'


                all_job_listings.append({
                    'Job Title': title,
                    'Company': company,
                    'Location': location,
                    'Country': country,
                    'Workplace': workplace,
                    'Experience': experience,
                    'Industry': industry,
                    'Salary': salary,
                    'Published Date': published_date
                })
            page_number += 1
        else:
            print("Main job listings container ('jobs-wrapper') not found on the page. Breaking loop.")
            break

    except requests.exceptions.HTTPError as errh:
        print(f"Http Error: {errh}")
        break
    except requests.exceptions.ConnectionError as errc:
        print(f"Error Connecting: {errc}")
        break
    except requests.exceptions.Timeout as errt:
        print(f"Timeout Error: {errt}")
        break
    except requests.exceptions.RequestException as err:
        print(f"Something went wrong: {err}")
        break
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        break

# After the loop, print the results
print(f"\nTotal job listings collected: {len(all_job_listings)}")
if all_job_listings:
    print("First 5 collected job listings:")
    for i, listing in enumerate(all_job_listings[:5]):
        print(f"  {i+1}. {listing}")
else:
    print("No job listings were collected.")
# Out:
# Scraping page: 1, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=1
# Scraping page: 2, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=2
# Scraping page: 3, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=3
# Scraping page: 4, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=4
# Scraping page: 5, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=5
# Scraping page: 6, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=6
# Scraping page: 7, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=7
# Scraping page: 8, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=8
# Scraping page: 9, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=9
# Scraping page: 10, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=10
# Scraping page: 11, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=11
# Scraping page: 12, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=12
# Scraping page: 13, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=13
# Scraping page: 14, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=14
# Scraping page: 15, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=15
# Scraping page: 16, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=16
# Scraping page: 17, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=17
# Scraping page: 18, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=18
# Scraping page: 19, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=19
# Scraping page: 20, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=20
# Scraping page: 21, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=21
# Scraping page: 22, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=22
# Scraping page: 23, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=23
# Scraping page: 24, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=24
# Scraping page: 25, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=25
# Scraping page: 26, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=26
# Scraping page: 27, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=27
# Scraping page: 28, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=28
# Scraping page: 29, URL: https://www.dataanalyst.com/data-analyst-jobs?c834b559_page=29
# No job listings found on page 29. Breaking loop.
#
# Total job listings collected: 418
# First 5 collected job listings:
#   1. {'Job Title': 'Data Analyst', 'Company': 'Thomson Reuters', 'Location': 'San Diego, CA', 'Country': 'United States', 'Workplace': 'In-office', 'Experience': '0 - 3 years', 'Industry': 'Tech', 'Salary': '$72,100 - $133,900', 'Published Date': 'Nov 3, 2025'}
#   2. {'Job Title': 'Data Analyst, Insights and Reporting', 'Company': 'Sony Music Entertainment', 'Location': 'New York, NY', 'Country': 'United States', 'Workplace': 'In-office', 'Experience': '0 - 3 years', 'Industry': 'Entertainment', 'Salary': '$64,000 - $70,000', 'Published Date': 'Aug 27, 2025'}
#   3. {'Job Title': 'Senior Data Analyst, Insights and Analytics', 'Company': 'Nintendo', 'Location': 'Redmond, WA', 'Country': 'United States', 'Workplace': 'Hybrid', 'Experience': '5 - 10 years', 'Industry': 'Tech', 'Salary': '$105,300 - $168,500', 'Published Date': 'Aug 27, 2025'}
#   4. {'Job Title': 'Lead Data Analyst', 'Company': 'SeatGeek', 'Location': 'New York, NY', 'Country': 'United States', 'Workplace': 'In-office', 'Experience': '5 - 10 years', 'Industry': 'Tech', 'Salary': '$125,000 - $180,000', 'Published Date': 'Aug 27, 2025'}
#   5. {'Job Title': 'Data Analyst', 'Company': 'Rent The Runway', 'Location': 'Brooklyn, NY', 'Country': 'United States', 'Workplace': 'In-office', 'Experience': '3 - 5 years', 'Industry': 'Retail', 'Salary': '$100,000 - $125,000', 'Published Date': 'Aug 27, 2025'}

# %% [markdown]
# **Reasoning**:
# The previous step successfully scraped all job listings and stored them in a list of dictionaries named `all_job_listings`. The next step is to convert this list into a pandas DataFrame and then save it to a CSV file as specified in the main task.

# %%
import pandas as pd

# Convert the list of dictionaries to a pandas DataFrame
df_job_listings = pd.DataFrame(all_job_listings)

# Define the CSV filename
csv_filename = 'job_listings.csv'

# Save the DataFrame to a CSV file
df_job_listings.to_csv(csv_filename, index=False)

print(f"Successfully saved {len(df_job_listings)} job listings to {csv_filename}")
print("First 5 rows of the DataFrame:")
df_job_listings.head()
# Out:
# Successfully saved 418 job listings to job_listings.csv
# First 5 rows of the DataFrame:
#                                      Job Title                   Company  \
# 0                                 Data Analyst           Thomson Reuters
# 1         Data Analyst, Insights and Reporting  Sony Music Entertainment
# 2  Senior Data Analyst, Insights and Analytics                  Nintendo
# 3                            Lead Data Analyst                  SeatGeek
# 4                                 Data Analyst           Rent The Runway
#
#         Location        Country  Workplace    Experience       Industry  \
# 0  San Diego, CA  United States  In-office   0 - 3 years           Tech
# 1   New York, NY  United States  In-office   0 - 3 years  Entertainment
# 2    Redmond, WA  United States     Hybrid  5 - 10 years           Tech
# 3   New York, NY  United States  In-office  5 - 10 years           Tech
# 4   Brooklyn, NY  United States  In-office   3 - 5 years         Retail
#
#                 Salary Published Date
# 0   $72,100 - $133,900    Nov 3, 2025
# 1    $64,000 - $70,000   Aug 27, 2025
# 2  $105,300 - $168,500   Aug 27, 2025
# 3  $125,000 - $180,000   Aug 27, 2025
# 4  $100,000 - $125,000   Aug 27, 2025

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   The web scraping process successfully collected a total of 418 data analyst job listings from the website.
# *   The script iterated through 28 pages of job listings, stopping when no further listings were found on page 29.
# *   For each listing, the following details were extracted: 'Job Title', 'Company', 'Location', 'Country', 'Workplace', 'Experience', 'Industry', 'Salary', and 'Published Date'. Missing information was recorded as 'N/A'.
# *   All collected job listings were successfully compiled into a Pandas DataFrame and saved to a CSV file named `job_listings.csv`.
#
# ### Insights or Next Steps
# *   The `job_listings.csv` file now contains a comprehensive dataset of data analyst jobs, which can be used for further analysis such as market trends, salary benchmarking, and demand for specific skills or locations.
# *   Given that web structures can change, regular maintenance and testing of the scraping script would be beneficial to ensure its continued functionality and accuracy in data collection.
